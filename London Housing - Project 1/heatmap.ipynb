# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np
# Load the pyplot collection of functions from matplotlib, as plt 
from matplotlib import pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
print(properties.head())
properties.shape
# Out:
#   Unnamed: 0 City of London Barking & Dagenham       Barnet       Bexley  \
# 0        NaT      E09000001          E09000002    E09000003    E09000004
# 1 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2 1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 3 1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 4 1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
#
#          Brent      Bromley       Camden      Croydon       Ealing  ...  \
# 0    E09000005    E09000006    E09000007    E09000008    E09000009  ...
# 1  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069  ...
# 2  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551  ...
# 3  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288  ...
# 4  72965.63094  81124.41227   120097.899  68610.04641  82188.90498  ...
#
#     NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  \
# ...

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
prop_t = properties.transpose()

# %%
prop_t.index
# Out:
# Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Unnamed: 34', 'Inner London', 'Outer London',
#        'Unnamed: 37', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')

# %%
prop_t = prop_t.reset_index()

# %%
prop_t.index
# Out:
# RangeIndex(start=0, stop=49, step=1)

# %%
prop_t.columns
# Out:
# Index(['index',       0,       1,       2,       3,       4,       5,       6,
#              7,       8,
#        ...
#            326,     327,     328,     329,     330,     331,     332,     333,
#            334,     335],
#       dtype='object', length=337)

# %%
prop_t.columns = prop_t.iloc[0]

# %%
prop_t = prop_t.drop(0)

# %%
prop_t.head()
# Out:
# 0          Unnamed: 0        NaT 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001         91448.98487         82202.77314
# 2  Barking & Dagenham  E09000002          50460.2266         51085.77983
# 3              Barnet  E09000003         93284.51832         93190.16963
# 4              Bexley  E09000004         64958.09036         64787.92069
# 5               Brent  E09000005         71306.56698         72022.26197
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1         79120.70256         77101.20804         84409.14932
# 2         51268.96956         53133.50526         53042.24852
# 3         92247.52435         90762.87492         90258.00033
# 4         64367.49344         64277.66881         63997.13588
# 5         72015.76274         72965.63094         73704.04743
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1         94900.51244         110128.0423         112329.4376  ...
# ...

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
prop_t = prop_t.rename(columns = {'Unnamed: 0':'Borough', pd.NaT: 'ID'})

# %%
prop_t.head()
# Out:
# 0             Borough         ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001         91448.98487         82202.77314
# 2  Barking & Dagenham  E09000002          50460.2266         51085.77983
# 3              Barnet  E09000003         93284.51832         93190.16963
# 4              Bexley  E09000004         64958.09036         64787.92069
# 5               Brent  E09000005         71306.56698         72022.26197
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1         79120.70256         77101.20804         84409.14932
# 2         51268.96956         53133.50526         53042.24852
# 3         92247.52435         90762.87492         90258.00033
# 4         64367.49344         64277.66881         63997.13588
# 5         72015.76274         72965.63094         73704.04743
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1         94900.51244         110128.0423         112329.4376  ...
# ...

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
prop_t_melt = prop_t.melt(id_vars=["Borough", "ID"])

# %%
print(prop_t_melt.head())
# Out:
#               Borough         ID          0        value
# 0      City of London  E09000001 1995-01-01  91448.98487
# 1  Barking & Dagenham  E09000002 1995-01-01   50460.2266
# 2              Barnet  E09000003 1995-01-01  93284.51832
# 3              Bexley  E09000004 1995-01-01  64958.09036
# 4               Brent  E09000005 1995-01-01  71306.56698

# %%
prop_t_melt = prop_t_melt.rename(columns={0: "Month", "value": "Average Prices"})

# %%
print(prop_t_melt.head())
# Out:
#               Borough         ID      Month Average Prices
# 0      City of London  E09000001 1995-01-01    91448.98487
# 1  Barking & Dagenham  E09000002 1995-01-01     50460.2266
# 2              Barnet  E09000003 1995-01-01    93284.51832
# 3              Bexley  E09000004 1995-01-01    64958.09036
# 4               Brent  E09000005 1995-01-01    71306.56698

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
prop_t_melt.dtypes
# Out:
# Borough                   object
# ID                        object
# Month             datetime64[ns]
# Average Prices            object
# dtype: object

# %%
prop_t_melt["Average Prices"] = pd.to_numeric(prop_t_melt["Average Prices"])
prop_t_melt.dtypes
# Out:
# Borough                   object
# ID                        object
# Month             datetime64[ns]
# Average Prices           float64
# dtype: object

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
prop_t_melt["Borough"].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Unnamed: 34',
#        'Inner London', 'Outer London', 'Unnamed: 37', 'NORTH EAST',
#        'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS',
#        'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST',
#        'SOUTH WEST', 'Unnamed: 47', 'England'], dtype=object)

# %%
prop_t_melt
# Out:
#                   Borough         ID      Month  Average Prices
# 0          City of London  E09000001 1995-01-01     91448.98487
# 1      Barking & Dagenham  E09000002 1995-01-01     50460.22660
# 2                  Barnet  E09000003 1995-01-01     93284.51832
# 3                  Bexley  E09000004 1995-01-01     64958.09036
# 4                   Brent  E09000005 1995-01-01     71306.56698
# ...                   ...        ...        ...             ...
# 16075              LONDON  E12000007 2022-11-01    542310.89724
# 16076          SOUTH EAST  E12000008 2022-11-01    402466.09073
# 16077          SOUTH WEST  E12000009 2022-11-01    337144.12190
# 16078         Unnamed: 47        NaN 2022-11-01             NaN
# 16079             England  E92000001 2022-11-01    315072.63643
#
# [16080 rows x 4 columns]

# %%
df = prop_t_melt.dropna()
df
# Out:
#                   Borough         ID      Month  Average Prices
# 0          City of London  E09000001 1995-01-01     91448.98487
# 1      Barking & Dagenham  E09000002 1995-01-01     50460.22660
# 2                  Barnet  E09000003 1995-01-01     93284.51832
# 3                  Bexley  E09000004 1995-01-01     64958.09036
# 4                   Brent  E09000005 1995-01-01     71306.56698
# ...                   ...        ...        ...             ...
# 16074     EAST OF ENGLAND  E12000006 2022-11-01    365144.26862
# 16075              LONDON  E12000007 2022-11-01    542310.89724
# 16076          SOUTH EAST  E12000008 2022-11-01    402466.09073
# 16077          SOUTH WEST  E12000009 2022-11-01    337144.12190
# 16079             England  E92000001 2022-11-01    315072.63643
#
# [15075 rows x 4 columns]

# %%
boroughs = ['Barking & Dagenham', 'Barnet', 'Bexley',
       'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
       'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
       'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
       'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
       'Lewisham', 'Merton', 'Newham', 'Redbridge',
       'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
       'Waltham Forest', 'Wandsworth', 'Westminster']

# %%
dfb = df[df.Borough.isin(boroughs)]
dfb.head()
# Out:
#               Borough         ID      Month  Average Prices
# 1  Barking & Dagenham  E09000002 1995-01-01     50460.22660
# 2              Barnet  E09000003 1995-01-01     93284.51832
# 3              Bexley  E09000004 1995-01-01     64958.09036
# 4               Brent  E09000005 1995-01-01     71306.56698
# 5             Bromley  E09000006 1995-01-01     81671.47692

# %%
non_boroughs = ['City of London', 'Unnamed: 34',
       'Inner London', 'Outer London', 'Unnamed: 37', 'NORTH EAST',
       'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS',
       'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST',
       'SOUTH WEST', 'Unnamed: 47', 'England']

# %%
dfnb = df[df.Borough.isin(non_boroughs)]
dfnb.Borough.unique()
# Out:
# array(['City of London', 'Inner London', 'Outer London', 'NORTH EAST',
#        'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS',
#        'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST',
#        'SOUTH WEST', 'England'], dtype=object)

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
bd_prices = dfb[dfb["Borough"] == "Barking & Dagenham"]

test = bd_prices.plot(kind="line", x="Month", y="Average Prices")

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
dfb = dfb.copy()

# %%
dfb["Year"] = dfb["Month"].apply(lambda t: t.year)
dfb.head()
# Out:
#               Borough         ID      Month  Average Prices  Year
# 1  Barking & Dagenham  E09000002 1995-01-01     50460.22660  1995
# 2              Barnet  E09000003 1995-01-01     93284.51832  1995
# 3              Bexley  E09000004 1995-01-01     64958.09036  1995
# 4               Brent  E09000005 1995-01-01     71306.56698  1995
# 5             Bromley  E09000006 1995-01-01     81671.47692  1995

# %%
dfb_group = dfb.groupby(by=["Borough", "Year"]).mean()
dfb_group
# Out:
#                          Average Prices
# Borough            Year
# Barking & Dagenham 1995    5.181797e+04
#                    1996    5.171819e+04
#                    1997    5.597426e+04
#                    1998    6.028582e+04
#                    1999    6.532093e+04
# ...                                 ...
# Westminster        2018    1.020025e+06
#                    2019    9.559986e+05
#                    2020    9.604692e+05
#                    2021    9.627774e+05
#                    2022    9.973779e+05
#
# [896 rows x 1 columns]

# %%
dfb_group = dfb_group.reset_index()
dfb_group
# Out:
#                 Borough  Year  Average Prices
# 0    Barking & Dagenham  1995    5.181797e+04
# 1    Barking & Dagenham  1996    5.171819e+04
# 2    Barking & Dagenham  1997    5.597426e+04
# 3    Barking & Dagenham  1998    6.028582e+04
# 4    Barking & Dagenham  1999    6.532093e+04
# ..                  ...   ...             ...
# 891         Westminster  2018    1.020025e+06
# 892         Westminster  2019    9.559986e+05
# 893         Westminster  2020    9.604692e+05
# 894         Westminster  2021    9.627774e+05
# 895         Westminster  2022    9.973779e+05
#
# [896 rows x 3 columns]

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
def create_price_ratio(dataframe):
    year_1998 = float(dataframe["Average Prices"][dataframe["Year"] == 1998])
    year_2018 = float(dataframe["Average Prices"][dataframe["Year"] == 2018])
    ratio = [year_2018/year_1998]
    return ratio

# %%
create_price_ratio(dfb_group[dfb_group["Borough"] == "Barking & Dagenham"])
# Out:
# [4.89661861291754]

# %%
final = {}

for b in dfb_group["Borough"].unique():
    borough = dfb_group[dfb_group["Borough"] == b]
    final[b] = create_price_ratio(borough)
print(final)
# Out:
# {'Barking & Dagenham': [4.89661861291754], 'Barnet': [4.358195917538044], 'Bexley': [4.248977046127877], 'Brent': [4.8945544971392865], 'Bromley': [4.094784685333876], 'Camden': [4.935353408884261], 'Croydon': [4.201100280024766], 'Ealing': [4.311450902121834], 'Enfield': [4.263471583495811], 'Greenwich': [4.7630363473291935], 'Hackney': [6.198285561008663], 'Hammersmith & Fulham': [4.13779810193623], 'Haringey': [5.134624964136042], 'Harrow': [4.0591964329643195], 'Havering': [4.325230371335307], 'Hillingdon': [4.2002730803844575], 'Hounslow': [3.976409106143329], 'Islington': [4.844048012802297], 'Kensington & Chelsea': [5.082465066092464], 'Kingston upon Thames': [4.270549521484271], 'Lambeth': [4.957751163514062], 'Lewisham': [5.449221041059686], 'Merton': [4.741273313294603], 'Newham': [5.305390437201879], 'Redbridge': [4.471182006097364], 'Richmond upon Thames': [4.005161895721457], 'Southwark': [5.516485302379378], 'Sutton': [4.118522608573157], 'Tower Hamlets': [4.62670104006
# ...

# %%
df_ratios = pd.DataFrame(final)
df_ratios
# Out:
#    Barking & Dagenham    Barnet    Bexley     Brent   Bromley    Camden  \
# 0            4.896619  4.358196  4.248977  4.894554  4.094785  4.935353
#
#    Croydon    Ealing   Enfield  Greenwich  ...    Merton   Newham  Redbridge  \
# 0   4.2011  4.311451  4.263472   4.763036  ...  4.741273  5.30539   4.471182
#
#    Richmond upon Thames  Southwark    Sutton  Tower Hamlets  Waltham Forest  \
# 0              4.005162   5.516485  4.118523       4.626701        5.834756
#
#    Wandsworth  Westminster
# 0    4.757709     5.353565
#
# [1 rows x 32 columns]

# %%
df_ratios_transpose = df_ratios.transpose()
df_ratios_transpose
# Out:
#                              0
# Barking & Dagenham    4.896619
# Barnet                4.358196
# Bexley                4.248977
# Brent                 4.894554
# Bromley               4.094785
# Camden                4.935353
# Croydon               4.201100
# Ealing                4.311451
# Enfield               4.263472
# Greenwich             4.763036
# Hackney               6.198286
# Hammersmith & Fulham  4.137798
# Haringey              5.134625
# Harrow                4.059196
# Havering              4.325230
# Hillingdon            4.200273
# Hounslow              3.976409
# Islington             4.844048
# Kensington & Chelsea  5.082465
# Kingston upon Thames  4.270550
# Lambeth               4.957751
# Lewisham              5.449221
# Merton                4.741273
# Newham                5.305390
# Redbridge             4.471182
# Richmond upon Thames  4.005162
# Southwark             5.516485
# Sutton                4.118523
# Tower Hamlets         4.626701
# ...

# %%
dfrt = df_ratios_transpose.reset_index()
dfrt
# Out:
#                    index         0
# 0     Barking & Dagenham  4.896619
# 1                 Barnet  4.358196
# 2                 Bexley  4.248977
# 3                  Brent  4.894554
# 4                Bromley  4.094785
# 5                 Camden  4.935353
# 6                Croydon  4.201100
# 7                 Ealing  4.311451
# 8                Enfield  4.263472
# 9              Greenwich  4.763036
# 10               Hackney  6.198286
# 11  Hammersmith & Fulham  4.137798
# 12              Haringey  5.134625
# 13                Harrow  4.059196
# 14              Havering  4.325230
# 15            Hillingdon  4.200273
# 16              Hounslow  3.976409
# 17             Islington  4.844048
# 18  Kensington & Chelsea  5.082465
# 19  Kingston upon Thames  4.270550
# 20               Lambeth  4.957751
# 21              Lewisham  5.449221
# 22                Merton  4.741273
# 23                Newham  5.305390
# 24             Redbridge  4.471182
# 25  Richmond upon Thames  4.005162
# ...

# %%
dfrt.rename(columns={'index':'Borough', 0:'Ratio 2018-1998'}, inplace=True)
dfrt.head()
# Out:
#               Borough  Ratio 2018-1998
# 0  Barking & Dagenham         4.896619
# 1              Barnet         4.358196
# 2              Bexley         4.248977
# 3               Brent         4.894554
# 4             Bromley         4.094785

# %%
dfr_sorted = dfrt.sort_values(by="Ratio 2018-1998", ascending=False)
dfr_sorted
# Out:
#                  Borough  Ratio 2018-1998
# 10               Hackney         6.198286
# 29        Waltham Forest         5.834756
# 26             Southwark         5.516485
# 21              Lewisham         5.449221
# 31           Westminster         5.353565
# 23                Newham         5.305390
# 12              Haringey         5.134625
# 18  Kensington & Chelsea         5.082465
# 20               Lambeth         4.957751
# 5                 Camden         4.935353
# 0     Barking & Dagenham         4.896619
# 3                  Brent         4.894554
# 17             Islington         4.844048
# 9              Greenwich         4.763036
# 30            Wandsworth         4.757709
# 22                Merton         4.741273
# 28         Tower Hamlets         4.626701
# 24             Redbridge         4.471182
# 1                 Barnet         4.358196
# 14              Havering         4.325230
# 7                 Ealing         4.311451
# ...

# %%
print(dfrt["Ratio 2018-1998"].mean())
print(dfrt["Ratio 2018-1998"].median())
# Out:
# 4.697941964274066
# 4.683987176677881

# %%
for i in range(6,24,3):
    dfrt.plot(kind="hist", bins=i, xlabel="Average Housing Price Increase, 1998-2018")

# %%
dfr_sorted = dfr_sorted.copy()

# %%
df_ratio_sorted = dfr_sorted.reset_index()

for i in range(1,33):
    df_ratio_sorted["index"][i-1] = i

df_ratio_sorted = df_ratio_sorted.rename(columns = {"index":"rank"})
df_ratio_sorted = df_ratio_sorted.set_index("rank")
df_ratio_sorted.to_csv("london_housing_increases_ranked.csv")
# Out:
# C:\Users\abrah\AppData\Local\Temp\ipykernel_24472\1744850977.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ratio_sorted["index"][i-1] = i

# %%
df_ratio_sorted = df_ratio_sorted.reset_index().drop("index", axis=1)
df_ratio_sorted.drop("level_0", axis=1)
# Out:
#     rank               Borough  Ratio 2018-1998
# 0      1               Hackney         6.198286
# 1      2        Waltham Forest         5.834756
# 2      3             Southwark         5.516485
# 3      4              Lewisham         5.449221
# 4      5           Westminster         5.353565
# 5      6                Newham         5.305390
# 6      7              Haringey         5.134625
# 7      8  Kensington & Chelsea         5.082465
# 8      9               Lambeth         4.957751
# 9     10                Camden         4.935353
# 10    11    Barking & Dagenham         4.896619
# 11    12                 Brent         4.894554
# 12    13             Islington         4.844048
# 13    14             Greenwich         4.763036
# 14    15            Wandsworth         4.757709
# 15    16                Merton         4.741273
# 16    17         Tower Hamlets         4.626701
# 17    18             Redbridge         4.471182
# 18    19                Barnet         4.358196
# ...

# %%
df_ranked_az = df_ratio_sorted
df_ranked_az["index"] = df_ranked_az.sort_values(by="Borough", inplace=True)

# %%
df_ranked_az = df_ranked_az.drop(["index", "level_0"], axis=1)

# %%
df_ranked_az.reset_index(inplace=True)

# %%
df_ranked_az.drop("index", axis=1)
# Out:
#     rank               Borough  Ratio 2018-1998  az
# 0     11    Barking & Dagenham         4.896619  11
# 1     19                Barnet         4.358196  19
# 2     24                Bexley         4.248977  24
# 3     12                 Brent         4.894554  12
# 4     29               Bromley         4.094785  29
# 5     10                Camden         4.935353  10
# 6     25               Croydon         4.201100  25
# 7     21                Ealing         4.311451  21
# 8     23               Enfield         4.263472  23
# 9     14             Greenwich         4.763036  14
# 10     1               Hackney         6.198286   1
# 11    27  Hammersmith & Fulham         4.137798  27
# 12     7              Haringey         5.134625   7
# 13    30                Harrow         4.059196  30
# 14    20              Havering         4.325230  20
# 15    26            Hillingdon         4.200273  26
# 16    32              Hounslow         3.976409  32
# ...

# %%
for i in range(1,33):
    df_ranked_az["index"][i-1] = i
# Out:
# C:\Users\abrah\AppData\Local\Temp\ipykernel_24472\3408821968.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ranked_az["index"][i-1] = i

# %%
dfnb = dfnb.copy()

# %%
df_ranked_az = df_ranked_az.rename(columns = {"a-z": "az"})

# %%
df_ranked_az
# Out:
#     az  rank               Borough  Ratio 2018-1998
# 0    1    11    Barking & Dagenham         4.896619
# 1    2    19                Barnet         4.358196
# 2    3    24                Bexley         4.248977
# 3    4    12                 Brent         4.894554
# 4    5    29               Bromley         4.094785
# 5    6    10                Camden         4.935353
# 6    7    25               Croydon         4.201100
# 7    8    21                Ealing         4.311451
# 8    9    23               Enfield         4.263472
# 9   10    14             Greenwich         4.763036
# 10  11     1               Hackney         6.198286
# 11  12    27  Hammersmith & Fulham         4.137798
# 12  13     7              Haringey         5.134625
# 13  14    30                Harrow         4.059196
# 14  15    20              Havering         4.325230
# 15  16    26            Hillingdon         4.200273
# 16  17    32              Hounslow         3.976409
# ...

# %%
dfnb["Year"] = dfnb["Month"].apply(lambda t: t.year)

dfnb_group = dfnb.groupby(by=["Borough", "Year"]).mean()

dfnb_group = dfnb_group.reset_index()

final_nonboroughs = {}
for b in dfnb_group["Borough"].unique():
    borough = dfnb_group[dfnb_group["Borough"] == b]
    final_nonboroughs[b] = create_price_ratio(borough)

dfnb_ratios = pd.DataFrame(final_nonboroughs)

dfnb_ratios_transpose = dfnb_ratios.transpose()

nb = dfnb_ratios_transpose.reset_index()

nb.rename(columns={'index':'Location', 0:'Ratio 2018-1998'}, inplace=True)


nb_sorted = nb.sort_values(by="Ratio 2018-1998", ascending=False)
nb_sorted
# Out:
#               Location  Ratio 2018-1998
# 0       City of London         5.301620
# 4         Inner London         5.170858
# 5               LONDON         4.679776
# 8         Outer London         4.418950
# 2      EAST OF ENGLAND         4.166901
# 9           SOUTH EAST         3.828388
# 3              England         3.810453
# 10          SOUTH WEST         3.795497
# 1        EAST MIDLANDS         3.632735
# 7           NORTH WEST         3.363416
# 12  YORKS & THE HUMBER         3.356065
# 11       WEST MIDLANDS         3.311262
# 6           NORTH EAST         2.828081

# %%
inner_london_list = ["Camden", "Greenwich", "Hackney", "Hammersmith & Fulham", "Islington", "Kensington & Chelsea", "Lambeth", "Lewisham", "Southwark", "Tower Hamlets", "Wandsworth", "Westminster"]
inner_london_list
# Out:
# ['Camden',
#  'Greenwich',
#  'Hackney',
#  'Hammersmith & Fulham',
#  'Islington',
#  'Kensington & Chelsea',
#  'Lambeth',
#  'Lewisham',
#  'Southwark',
#  'Tower Hamlets',
#  'Wandsworth',
#  'Westminster']

# %%
dfr_sorted.to_csv("london_housing_ratios_1998-2018.csv")

# %%
import geopandas as gpd

# %%
london_map = gpd.read_file("London_Borough_Excluding_MHW.shp")
stats = pd.read_csv("london_housing_increases_ranked.csv")

# %%
print(london_map)
# Out:
#                       NAME   GSS_CODE   HECTARES  NONLD_AREA ONS_INNER  \
# 0     Kingston upon Thames  E09000021   3726.117       0.000         F
# 1                  Croydon  E09000008   8649.441       0.000         F
# 2                  Bromley  E09000006  15013.487       0.000         F
# 3                 Hounslow  E09000018   5658.541      60.755         F
# 4                   Ealing  E09000009   5554.428       0.000         F
# 5                 Havering  E09000016  11445.735     210.763         F
# 6               Hillingdon  E09000017  11570.063       0.000         F
# 7                   Harrow  E09000015   5046.330       0.000         F
# 8                    Brent  E09000005   4323.270       0.000         F
# 9                   Barnet  E09000003   8674.837       0.000         F
# 10                 Lambeth  E09000022   2724.940      43.927         T
# 11               Southwark  E09000028   2991.340     105.139         T
# ...

# %%
london_map = london_map.set_geometry('geometry')

# %%
print(london_map)
# Out:
#                       NAME   GSS_CODE   HECTARES  NONLD_AREA ONS_INNER  \
# 0     Kingston upon Thames  E09000021   3726.117       0.000         F
# 1                  Croydon  E09000008   8649.441       0.000         F
# 2                  Bromley  E09000006  15013.487       0.000         F
# 3                 Hounslow  E09000018   5658.541      60.755         F
# 4                   Ealing  E09000009   5554.428       0.000         F
# 5                 Havering  E09000016  11445.735     210.763         F
# 6               Hillingdon  E09000017  11570.063       0.000         F
# 7                   Harrow  E09000015   5046.330       0.000         F
# 8                    Brent  E09000005   4323.270       0.000         F
# 9                   Barnet  E09000003   8674.837       0.000         F
# 10                 Lambeth  E09000022   2724.940      43.927         T
# 11               Southwark  E09000028   2991.340     105.139         T
# ...

# %%
london_map.plot()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

# %%
london_map.plot(ax=ax)
# Out:
# <AxesSubplot:>

# %%
london_az = london_map.sort_values(by="NAME").reset_index()

# %%
london_az = london_az.set_index("NAME")

# %%
london_az = london_az.drop("City of London")

# %%
london_az = london_az.reset_index()

# %%
for i in range(1, 33):
    london_az["index"][i-1] = i
# Out:
# C:\Users\abrah\AppData\Local\Temp\ipykernel_24472\2182794899.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   london_az["index"][i-1] = i

# %%
london_az = london_az.rename({"index": "az"}, axis=1)

# %%
london_az
# Out:
#                       NAME  az   GSS_CODE   HECTARES  NONLD_AREA ONS_INNER  \
# 0     Barking and Dagenham   1  E09000002   3779.934     169.150         F
# 1                   Barnet   2  E09000003   8674.837       0.000         F
# 2                   Bexley   3  E09000004   6428.649     370.619         F
# 3                    Brent   4  E09000005   4323.270       0.000         F
# 4                  Bromley   5  E09000006  15013.487       0.000         F
# 5                   Camden   6  E09000007   2178.932       0.000         T
# 6                  Croydon   7  E09000008   8649.441       0.000         F
# 7                   Ealing   8  E09000009   5554.428       0.000         F
# 8                  Enfield   9  E09000010   8220.025       0.000         F
# 9                Greenwich  10  E09000011   5044.190     310.785         F
# 10                 Hackney  11  E09000012   1904.902       0.000         T
# ...

# %%
map_and_stats=london_az.merge(df_ranked_az, on="az")

# %%
map_and_stats
# Out:
#                       NAME  az   GSS_CODE   HECTARES  NONLD_AREA ONS_INNER  \
# 0     Barking and Dagenham   1  E09000002   3779.934     169.150         F
# 1                   Barnet   2  E09000003   8674.837       0.000         F
# 2                   Bexley   3  E09000004   6428.649     370.619         F
# 3                    Brent   4  E09000005   4323.270       0.000         F
# 4                  Bromley   5  E09000006  15013.487       0.000         F
# 5                   Camden   6  E09000007   2178.932       0.000         T
# 6                  Croydon   7  E09000008   8649.441       0.000         F
# 7                   Ealing   8  E09000009   5554.428       0.000         F
# 8                  Enfield   9  E09000010   8220.025       0.000         F
# 9                Greenwich  10  E09000011   5044.190     310.785         F
# 10                 Hackney  11  E09000012   1904.902       0.000         T
# ...

# %%
fig, ax = plt.subplots(1, figsize=(8, 8))
plt.xticks(rotation=90)
map_and_stats.plot(column="Ratio 2018-1998", cmap="Reds", linewidth=0.4, ax=ax, edgecolor=".4")
# Out:
# <AxesSubplot:>

# %%
bar_info = plt.cm.ScalarMappable(cmap="Reds", norm=plt.Normalize(vmin=0, vmax=20))
bar_info._A = []
cbar = fig.colorbar(bar_info)

# %%
fig, ax = plt.subplots(1, figsize=(8, 8))
ax.axis("off")
map_and_stats.plot(column="Ratio 2018-1998", cmap="Reds", linewidth=0.4, ax=ax, edgecolor=".4")
# Out:
# <AxesSubplot:>

# %%
map_and_stats["coords"] = map_and_stats["geometry"].apply(lambda x: x.representative_point().coords[:])
map_and_stats["coords"] = [coords[0] for coords in map_and_stats["coords"]]
fig, ax = plt.subplots(1, figsize=(8, 8))
map_and_stats.plot(ax=ax, column="Ratio 2018-1998", cmap="Reds", edgecolor="black")
ax.axis("off")
for idx, row in map_and_stats.iterrows():
    plt.annotate(text=row["rank"], xy = row["coords"], horizontalalignment="center", color ="black")

# %%
map_and_stats
# Out:
#                       NAME  az   GSS_CODE   HECTARES  NONLD_AREA ONS_INNER  \
# 0     Barking and Dagenham   1  E09000002   3779.934     169.150         F
# 1                   Barnet   2  E09000003   8674.837       0.000         F
# 2                   Bexley   3  E09000004   6428.649     370.619         F
# 3                    Brent   4  E09000005   4323.270       0.000         F
# 4                  Bromley   5  E09000006  15013.487       0.000         F
# 5                   Camden   6  E09000007   2178.932       0.000         T
# 6                  Croydon   7  E09000008   8649.441       0.000         F
# 7                   Ealing   8  E09000009   5554.428       0.000         F
# 8                  Enfield   9  E09000010   8220.025       0.000         F
# 9                Greenwich  10  E09000011   5044.190     310.785         F
# 10                 Hackney  11  E09000012   1904.902       0.000         T
# ...

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!
